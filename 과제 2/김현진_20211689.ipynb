# %% [markdown]
# <h1><span style="color:black; background-color:pink"><b>과제 유의사항 안내</b></span></h1>
#
# 1. 가장 먼저 ipynb 파일명을 자신의 이름과 학번으로 수정하고, 작업을 진행하세요. e.g. 솜솜이_20250405.ipynb<br>
# 2. .py 파일로 답안을 제출하는 것은 불가능하며, .ipynb 파일로만 제출 가능합니다.<br>
# 3. 제공된 csv 파일의 행 또는 열을 임의로 삭제하거나 추가하는 등 csv 파일을 수정하는 것은 허용하지 않습니다.<br>
# 4. 각 문제마다, 문제 해결에 필요한 라이브러리를 import하는 부분은 이미 작성되어 있습니다.<br>
# 5. 문제마다 소스 코드를 여러 셀(Cells)에 나누어 작성해도 좋으나, 과제 제출 전에 단축키 d, d를 눌러서 불필요한 셀을 제거하세요.<br>
# 6. 채점은 문제마다 독립적으로 이루어지며, 담당 교수(권범)의 노트북 환경에서 문제마다 [▶] 버튼을 눌렀을 때 정상 실행 및 요구한 결과가 올바르게 출력되는지 여부로 평가합니다.<br>
# 7. [▶] 버튼 클릭 시, Error 메시지가 출력될 경우 해당 문제는 0점 처리됩니다(부분 점수 없음).<br>
# 8. [▶] 버튼 클릭 시, Warning 메시지가 출력될 경우 해당 문제는 0점 또는 감점 받을 수 있습니다.<br>
# 9. [▶] 버튼 클릭 시, 문제에서 요구하지 않은 결과물이 출력될 경우 해당 문제는 0점 또는 감점 받을 수 있습니다.<br>
# 10. 작성 완료한 파일을 제출하기 전에 [▶] 버튼을 클릭해서, 자신이 작성한 소스 코드가 오류 없이 정상 작동하는지 그리고 결과물이 제대로 출력되는지 확인 후 제출하세요.

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 1 (0.5 points)</b></span></h3>
# NumPy 라이브러리에는 난수를 생성해 주는 randn( ) 함수가 있다. 솜솜이는 이 함수가 표준 정규분포로 난수를 생성해 준다는 것을 알게됐다. 문득, 솜솜이는 randn( ) 함수에 의해 생성되는 난수가 표준 정규분포를 따르는 것이 맞는지 검증해 보고 싶어졌다. 솜솜이를 도와 표준 정규분포로 일백만 개의 난수를 생성시키고 이를 히스토그램으로 시각화하세요. 또한, 평균이 5이고 표준편차가 2인 정규분포로 일백만 개의 난수를 생성시키고 이를 히스토그램으로 시각화하세요. 마지막으로 평균이 -1이고 표준편차가 3인 정규분포로 일백만 개의 난수를 생성시키고 이를 히스토그램으로 시각화하세요.
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 그래프의 가로 및 세로 길이는 기본값으로 사용하세요.<br>
# * 그래프의 제목, 격자, 범례 등 세부 사항은 셀 아래 그래프를 참고하여 설정하세요.<br>
# * 히스토그램의 투명도는 0.7로 지정하고, bins는 1000으로 지정하세요.<br>
# * 세 가지 정규분포 그래프를 구별하기 위해 빨간색, 초록색, 파란색을 셀 아래 그래프를 참고하여 설정하세요.<br>
# * **[Tip]** 히스토그램 함수 안에는 density 매개변수가 있으며, 이를 True로 설정하면 아래 그래프의 y축과 같이 표시할 수 있습니다.<br>
#
# <h4><b>솜솜이가 얻어야 하는 화면</b></h4>

# %% [markdown]
# ![img-1.png](attachment:0474c6e4-1fa0-4752-9265-08c064fc0070.png)

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# 아래부터 솜솜이가 작성해야 할 부분
plt.figure()
plt.title("Probability Density Funtion (PDF)")
a = np.random.randn(1000000) # 일백만 개의 난수
b = np.random.randn(1000000) * 2 + 5 # 평균이 5이고 표준편차가 2
c = np.random.randn(1000000) * 3 - 1 # 평균이 -1이고 표준편차가 3

plt.hist(a, bins=1000, color='green', label='N(0, 1)', density=True, alpha=0.7)
plt.hist(b, bins=1000, color='red', label='N(5, 4)', density=True, alpha=0.7)
plt.hist(c, bins=1000, color='blue', label='N(-1, 9)', density=True, alpha=0.7)

plt.legend(loc=1)
plt.grid()

plt.show()

# 수고하셨습니다.

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 2 (0.5 points)</b></span></h3>
# gangnam_station.csv 파일에는 1월 한달간 강남역의 공기질 측정 데이터가 시간대별로 기록돼 있다. 시간대별 강남역의 공기질 데이터를 상자 그림으로 시각화하세요.
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 그래프의 가로 및 세로 길이(단위: inch)는 각각 10, 3으로 설정하세요.<br>
# * 그래프의 제목, 가로세로 축의 이름, 격자 등 세부 사항은 셀 아래 그래프를 참고하여 설정하세요.<br>
# * **[Tip]** tick_labels 매개변수에 상자들의 위치를 지정하세요.<br>
#
# <h4><b>솜솜이가 얻어야 하는 그래프</b></h4>

# %% [markdown]
# ![img-2.png](attachment:2c44a2f6-d689-4cbb-abec-8de9d0c4f4e0.png)

# %%
import csv
import matplotlib.pyplot as plt

f = open("gangnam_station.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
header = next(data)
# print(header)

time = [[], [], [], [],
       [], [], [], [],
       [], [], [], [],
       [], [], [], [],
       [], [], [], [],
       [], [], [], []]

for row in data:
    # print(row[2].split(' ')[1])
    hour = int(row[2].split(' ')[1])
    air = float(row[3])
    time[hour].append(air)

# print(time)

plt.figure(figsize=(10,3))

plt.boxplot(time, showfliers=False)

plt.xticks(range(1, 25, 1), range(0, 24, 1))

plt.title("Air Quality of Gangnam Station")
plt.xlabel("Time (h)")
plt.ylabel("Air Quality")
plt.grid()

plt.show()
    
# 수고하셨습니다.
f.close()

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 3 (0.5 points)</b></span></h3>
# rainfall.csv 파일로부터 우리나라 서울 지역의 월평균 강수량을 분석해 막대그래프로 시각화하세요.<br>
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 그래프의 가로 및 세로 길이(단위: inch)는 각각 10, 3으로 설정하세요.<br>
# * 막대그래프에서 막대의 색상은 파란색으로 설정하세요.<br>
# * 그래프의 제목, 가로세로 축의 이름, 격자 등 세부 사항은 셀 아래 그래프를 참고하여 설정하세요.<br>
#
# <h4><b>솜솜이가 얻어야 하는 그래프</b></h4>

# %% [markdown]
# ![img-3.png](attachment:ad566f17-0938-4388-8796-ac1062100e21.png)

# %%
import csv
import matplotlib.pyplot as plt

f = open("rainfall.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
for i in range(7):
    next(data)
h = next(data)
# print(h)

month = [0] * 12
day = [0] * 12

# print(month)

for row in data:
    # print(row)
    # print(int(row[0].split('-')[1]))
    day[int(row[0].split('-')[1]) - 1] += 1
    if row[2] != '':
        month[int(row[0].split('-')[1]) - 1] += float(row[2])
        # day[int(row[0].split('-')[1]) - 1] += 1
        
# print(month)
# print(len(month)) # 12

avg_rain = [0] * 12
for i in range(12):
    if day[i] > 0:
        # print(i, len(month[i]))
        avg_rain[i] = month[i] / day[i]
    else:
        avg_rain[i] = 0

# print(avg_rain)
# print(len(avg_rain)) # 12

plt.figure(figsize=(10,3))

plt.bar(range(1, len(avg_rain)+1, 1), avg_rain, color="blue")

plt.xticks(range(1, 13, 1), range(1, 13, 1))

plt.title("Average Annual Rainfall in Seoul")
plt.xlabel("Month")
plt.ylabel("Average Annual Rainfall (mm)")
plt.grid()

plt.show()

# 수고하셨습니다.
f.close()

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 4 (0.5 points)</b></span></h3>
# world_temperature.csv 파일에는 세계 기후 평년값 데이터가 기록돼 있다. 올해 여름 방학 때, 일본 여행을 계획 중인 솜솜이는 삽포로와 오사까 지역을 여행 후보 지역으로 고려 중에 있다. 파일 내 '평균기온(°C)' 열에 기록되어 있는 데이터를 토대로 삽포로 지역과 오사까 지역의 월별 평균 기온을 수평 막대그래프로 시각화하세요.
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 그래프의 가로 및 세로 길이는 기본값으로 사용하세요.<br>
# * Windows 운영체제 사용자 기준으로, 폰트는 맑은 고딕으로 지정하세요.<br>
# * 그래프의 제목, 가로세로 축의 이름, 격자, 범례 등 세부 사항은 셀 아래 그래프를 참고하여 설정하세요.<br>
# * 삽포로 지역에 대한 막대그래프는 하늘색(skyblue), 오사까 지역에 대한 막대그래프는 분홍색(pink)으로 설정하세요.<br>
#
# <h4><b>솜솜이가 얻어야 하는 그래프</b></h4>

# %% [markdown]
# ![img-4.png](attachment:1a05038d-d0f6-4b3a-944b-9842239d5b73.png)

# %%
import csv
import matplotlib.pyplot as plt

f = open("world_temperature.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
for i in range(5):
    next(data)
h = next(data)
# print(h)

saporo = []
osaka = []
for row in data:
    if row[1] == "삽포로":
        saporo.append(float(row[6]))
        # print(row)
    if row[1] == "오사까":
        osaka.append(float(row[6]))
        # print(row)

plt.rc("font", family="Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

y_osaka = range(13, 25)
y_saporo = range(1, 13)

plt.figure()

plt.barh(y_saporo, saporo, label="삽포로", color="skyblue")
plt.barh(y_osaka, osaka, label="오사까", color="pink")

plt.yticks(
    list(y_osaka) + list(y_saporo),
    [str(i) for i in range(1, 13)] + [str(i) for i in range(1, 13)]
)

plt.title("일본 삽포로, 오사까 지역의 월별 평균기온 비교")
plt.xlabel("평균 기온")
plt.ylabel("월")
plt.grid()
plt.legend()

plt.show()

# 수고하셨습니다.
f.close()

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 5 (0.5 points)</b></span></h3>
# busan_coffe.csv 파일에는 부산광역시 서구 지역에 등록된 커피판매점 데이터가 기록돼 있다. 평소 커피를 즐겨 마시는 솜솜이는 부산광역시 서구에 소재하는 커피 가맹점의 비율을 조사하고자 한다. 조사 대상 커피 가맹점은 '공차', '스타벅스', '이디야', '투썸플레이스', '컴포즈', '할리스'로 정했다. 솜솜이를 도와, 부산광역시 서구에 조사 대상 커피 가맹점의 비율을 파이 차트로 시각화하세요.
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 그래프의 가로 및 세로 길이는 기본값으로 사용하세요.<br>
# * 파이 차트에 커피 가맹점의 이름과 각 가맹점의 비율을 표시하세요.
# * Windows 운영체제 사용자 기준으로, 폰트는 맑은 고딕으로 지정하세요.<br>
# * 공차는 빨간색, 스타벅스는 주황색, 이디야는 노란색, 투썸플레이스는 초록색, 컴포즈는 딥 스카이 블루(deepskyblue), 할리스는 은색(silver)으로 색상을 설정하세요.<br>
# * 부채꼴의 시작 각도는 아래 그래프를 참고하여 설정하세요.<br>
#
# <h4><b>솜솜이가 얻어야 하는 그래프</b></h4>

# %% [markdown]
# ![img-5.png](attachment:b3864d19-6b85-4f06-b39f-acfbbeeebf59.png)

# %%
import csv
import matplotlib.pyplot as plt

f = open("busan_coffe.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
header = next(data)
# print(header)

# '공차', '스타벅스', '이디야', '투썸플레이스', '컴포즈', '할리스'
gongcha = 0
starbucks = 0
ediya = 0
twosome = 0
compose = 0
hollys = 0
for row in data:
    if '공차' in row[0]:
        gongcha += 1
    if '스타벅스' in row[0]:
        starbucks += 1
    if '이디야' in row[0]:
        ediya += 1
    if '투썸플레이스' in row[0]:
        twosome += 1
    if '컴포즈' in row[0]:
        compose += 1
    if '할리스' in row[0]:
        hollys += 1

# print(starbucks)
# print(compose)

coffee = [gongcha, starbucks, ediya, twosome, compose, hollys]
label = ['공차', '스타벅스', '이디야', '투썸플레이스', '컴포즈', '할리스']
color = ['red', 'orange', 'yellow', 'green', 'deepskyblue', 'lightgray']

plt.figure()

plt.pie(coffee, labels=label, colors=color, autopct="%.f%%", startangle=90)

plt.show()
    
# 수고하셨습니다.
f.close()

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 6 (0.5 points)</b></span></h3>
# korea_temperature.csv 파일로부터 우리나라의 지역별 최고기온과 강수량을 분석해 산점도로 시각화하세요.<br>
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 그래프의 가로 및 세로 길이는 기본값으로 사용하세요.<br>
# * 지역별 경도와 위도 정보를 각각 점의 x, y 좌표로 활용하세요.<br>
# * 지역별 최고기온 데이터를 활용해 점의 색상을 지정하세요.<br>
# * 컬러맵은 "hot"으로 지정하고, 투명도는 0.7로 설정하세요.<br>
# * 지역별 강우량 데이터를 활용해 점의 크기를 지정하세요.<br>
# * 그래프의 가로세로 축의 이름, 격자 등 세부 사항은 셀 아래 그래프를 참고하여 설정하세요.<br>
#
# <h4><b>솜솜이가 얻어야 하는 그래프</b></h4>

# %% [markdown]
# ![img-6.png](attachment:e36df1d9-5131-4da7-81db-5913753cabe3.png)

# %%
import csv
import matplotlib.pyplot as plt

f = open("korea_temperature.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
header = next(data)
# print(header)

# '최고기온(°C)', '강수량(mm)' -2, -1
# 경도, 위도 1, 2

lon = [] # 경도 1
lat = [] # 위도
color = []
size = []
for row in data:
    # print(row)
    
    lon.append(float(row[1]))
    lat.append(float(row[2]))
    
    color.append(float(row[-2]))
    size.append(float(row[-1]))
    
    
plt.figure()

plt.scatter(lon, lat, 
            c=color, 
            cmap="hot", 
            alpha=0.7,
            s=size)
# plt.plot(range(0, max(male), 1), range(0, max(male), 1), color="black")
plt.colorbar()

plt.xlabel("Longitude (E)") # 경도 1
plt.ylabel("Latitude (N)")
plt.grid()
plt.show()
    
# 수고하셨습니다.
f.close()

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 7 (0.5 points)</b></span></h3>
# ※ 고령화 사회: 65세 이상 인구가 전체 인구에서 차지하는 비율이 7% 이상<br>
# ※ 고령 사회: 65세 이상 인구가 전체 인구에서 차지하는 비율이 14% 이상<br>
# ※ 초고령 사회: 65세 이상 인구가 전체 인구에서 차지하는 비율이 20% 이상<br>
# seoul_old_people.csv 파일에는 서울 내 행정지역별로 고령 인구수 데이터가 저장돼 있습니다. 솜솜이는 이 데이터로부터 서울 내 행정구역들을 고령화 사회, 고령 사회, 초고령 사회를 기준으로 구분하려고 합니다. 고령화 사회, 고령 사회, 초고령 사회의 정의에 따라, 이번에는 행정구역별로 65세 이상 인구수를 해당 행정구역의 전체 인구수로 나눈 비율 값(고령 인구 비율)을 이용하려고 합니다. 계산해 보면 알 수 있겠지만, 서울 내 25개 행정구역은 모두 초고령 사회(7개) 또는 고령 사회(18개)로 진입했습니다. 솜솜이를 도와 각 행정구역을 초고령 사회 및 고령 사회를 기준으로 구분하고, 구분에 따라 지역명과 고령 인구 비율 값을 출력시킬 수 있도록, 알고리즘을 구현하세요.
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 아래 '결과 화면'과 **100% 동일한** 결과가 출력되도록, print( ) 함수를 적절히 활용하세요.<br>
# * 출력되는 결과 화면에서 띄어쓰기도 평가 요소에 포함되며, 동일하지 않은 정도에 따라 감점이 있습니다.<br>
# * '결과 화면'에서 <span style="color:blue">파란색</span>으로 표시된 부분은, 문자열이 아닌 변수를 활용해 출력돼야 합니다.<br>
# * 고령 인구 비율 값은 소수 4째 자리에서 반올림하여, 소수 3째 자리까지 보일 수 있도록 출력시키세요.<br>

# %% [markdown]
# <h4><b>솜솜이가 출력시켜야 하는 결과 화면</b></h4>
# <초고령 사회로 진입한 지역><br>
# <span style="color:blue">
#     1 종로구 0.207<br>
#     2 중구  0.213<br>
#     3 중랑구 0.21<br>
#     4 강북구 0.242<br>
#     5 도봉구 0.233<br>
#     6 은평구 0.204<br>
#     7 구로구 0.203</span><br><br>
# <고령 사회로 진입한 지역><br>
# <span style="color:blue">
#     1 용산구 0.186<br>
#     2 성동구 0.18<br>
#     3 광진구 0.171<br>
#     4 동대문 0.198<br>
#     5 성북구 0.191<br>
#     6 노원구 0.196<br>
#     7 서대문 0.19<br>
#     8 마포구 0.16<br>
#     9 양천구 0.178<br>
#     10 강서구 0.184<br>
#     11 금천구 0.199<br>
#     12 영등포 0.178<br>
#     13 동작구 0.187<br>
#     14 관악구 0.178<br>
#     15 서초구 0.163<br>
#     16 강남구 0.16<br>
#     17 송파구 0.169<br>
#     18 강동구 0.183</span>

# %%
import csv
import matplotlib.pyplot as plt

f = open("seoul_old_people.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
header = next(data)
# print(header)
next(data)

oldest = []
older = []
old = []
for row in data:
    # print(row)

    for j in range(1, 7, 1):
        row[j] = row[j].replace(',', '')

    row[1:] = map(int, row[1:])
    # print(row)

    # 행정구역별로 65세 이상 인구수를 해당 행정구역의 전체 인구수로 나눈 비율 값(고령 인구 비율)
    how = row[4] / row[1]
    # print(round(how, 3))

    if 0.20 <= round(how, 3):
        oldest.append(row[0].split(' ')[2] + ' ' + str(round(how, 3)))
    elif 0.14 <= round(how, 3):
        older.append(row[0].split(' ')[2] + ' ' + str(round(how, 3)))
    elif 0.07 <= round(how, 3):
        old.append(row[0].split(' ')[2] + ' ' + str(round(how, 3)))

# print(oldest)
# print(older)
# print(old)

print("<초고령 사회로 진입한 지역>")
for i in range(len(oldest)):
    print(i+1, oldest[i])

print()
print("<고령 사회로 진입한 지역>")  
for i in range(len(older)):
    print(i+1, older[i])

# 수고하셨습니다.
f.close()
# Out:
# <초고령 사회로 진입한 지역>
# 1 종로구 0.207
# 2 중구 0.213
# 3 중랑구 0.21
# 4 강북구 0.242
# 5 도봉구 0.233
# 6 은평구 0.204
# 7 구로구 0.203
#
# <고령 사회로 진입한 지역>
# 1 용산구 0.186
# 2 성동구 0.18
# 3 광진구 0.171
# 4 동대문구 0.198
# 5 성북구 0.191
# 6 노원구 0.196
# 7 서대문구 0.19
# 8 마포구 0.16
# 9 양천구 0.178
# 10 강서구 0.184
# 11 금천구 0.199
# 12 영등포구 0.178
# 13 동작구 0.187
# 14 관악구 0.178
# 15 서초구 0.163
# 16 강남구 0.16
# 17 송파구 0.169
# 18 강동구 0.183

# %% [markdown]
# <h3><span style="color:black; background-color:skyblue"><b>문제 8 (0.5 points)</b></span></h3>
# ※ 아동: 아동복지법 제3조제1호에서 규정하고 있는 18세 미만인 사람<br>
# ※ 청소년: 청소년기본법 제3조제1호에서 규정하고 있는 9세 이상 24세 이하인 사람<br>
# ※ 청년: 청년기본법 제3조에서 규정하고 있는 19∼34세인 사람<br>
#
# seoul_young_people.csv 파일에는 3월 기준으로, 서울 내 행정지역별로 아동, 청소년, 청년 인구수 데이터가 저장돼 있습니다. 이 데이터로부터 아동, 청소년, 청년 인구수가 가장 많은 지역이 각각 어디인지 찾고 지역명과 해당 인구수를 출력시킬 수 있도록, 알고리즘을 구현하세요.
#
# <h4><b>제약사항 및 주의사항</b></h4>
#
# * 외부 라이브러리(예: pandas)에서 제공하는 함수 또는 클래스 등을 사용할 경우, 0점 처리됩니다.<br>
# * 아래 '결과 화면'과 **100% 동일한** 결과가 출력되도록, print( ) 함수를 적절히 활용하세요.<br>
# * 출력되는 결과 화면에서 띄어쓰기도 평가 요소에 포함되며, 동일하지 않은 정도에 따라 감점이 있습니다.<br>
# * '결과 화면'에서 <span style="color:blue">파란색</span>으로 표시된 부분은, 문자열이 아닌 변수를 활용해 출력돼야 합니다.<br>
#
# <h4><b>솜솜이가 출력시켜야 하는 결과 화면</b></h4>
# 아동이 가장 많이 사는 지역과 아동 인구수: <span style="color:blue">송파구 89,030</span>명<br>
# 청소년이 가장 많이 사는 지역과 청소년 인구수: <span style="color:blue">강남구 97,040</span>명<br>
# 청년이 가장 많이 사는 지역과 청년 인구수: <span style="color:blue">관악구 166,647</span>명

# %%
import csv
import matplotlib.pyplot as plt

f = open("seoul_young_people.csv", 'r', encoding="cp949")
data = csv.reader(f)

# 아래부터 솜솜이가 작성해야 할 부분
header = next(data)
# print(header)
next(data)

child = 0
child_best_loc = []
teen = 0
teen_best_loc = []
young = 0
young_best_loc = []
for row in data:
    # print(row)
    for j in range(1, 13, 1):
        # print(row)
        row[j] = row[j].replace(',', '')

    row[1:] = map(int, row[1:])
    # print(row[4])
    if child < int(row[4]):
        child = row[4]
        child_best_loc = row[0].split(' ')[2]
    if teen < int(row[7]):
        teen = row[7]
        teen_best_loc = row[0].split(' ')[2]
    if young < int(row[10]):
        young = row[10]
        young_best_loc = row[0].split(' ')[2]

# print(child_best_loc, child)
# print(teen_best_loc, teen)
# print(young_best_loc, young)
# print(f"{1234567890:,}") 

print("아동이 가장 많이 사는 지역과 아동 인구수: ", child_best_loc, ' ', f"{child:,}" , "명", sep='')
print("청소년이 가장 많이 사는 지역과 청소년 인구수: ", teen_best_loc, ' ', f"{teen:,}" , "명", sep='')
print("청년이 가장 많이 사는 지역과 청년 인구수: ", young_best_loc, ' ', f"{young:,}" , "명", sep='')

# print("아동이 가장 많이 사는 지역과 아동 인구수: 송파구 89,030명")
# print("청소년이 가장 많이 사는 지역과 청소년 인구수: 강남구 97,040명")
# print("청년이 가장 많이 사는 지역과 청년 인구수: 관악구 166,647명")

# 수고하셨습니다.
f.close()
# Out:
# 아동이 가장 많이 사는 지역과 아동 인구수: 송파구 89,030명
# 청소년이 가장 많이 사는 지역과 청소년 인구수: 강남구 97,040명
# 청년이 가장 많이 사는 지역과 청년 인구수: 관악구 166,647명
